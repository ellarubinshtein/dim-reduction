# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# LaTeX + serif style
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'
sns.set(style="whitegrid")  # optional for subtle background grid

# Parameters
T = 100
x0 = 0.5
r_values = [2.0, 2.5, 2.887, 3.0, 3.449, 3.556, 3.679, 3.720, 3.8]
colors = ["#000000", "#33ccff", "#cc33ff", 
          "#ffcc00", "#ff0000", "#66ff33", 
          "#ff0066", "#0000ff", "#ff00ff"]

# Create 3x3 subplot figure
fig, axes = plt.subplots(3, 3, figsize=(14, 12))
axes = axes.flatten()

for i, (r, color) in enumerate(zip(r_values, colors)):
    x = np.zeros(T)
    x[0] = x0
    for t in range(1, T):
        x[t] = r * x[t-1] * (1 - x[t-1])
    
    ax = axes[i]
    ax.plot(range(T), x, lw=2, color=color, marker='o', markersize=4, markevery=3)
    ax.set_title(f"$r = {r}$", fontsize=20, fontweight='bold')
    ax.set_xlabel(r"$t$", fontsize=10)
    ax.set_ylabel(r"$x_t$", fontsize=10)
    
    # # Grid style
    # ax.grid(True, which="major", linestyle="--", alpha=0.5)
    # ax.grid(True, which="minor", linestyle=":", alpha=0.25)
    # ax.minorticks_on()
    ax.grid(False)

    # Remove top and right spines
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# LaTeX + serif style
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'
sns.set(style="white")

# Parameters
T = 50
x0 = 0.5
r_values = [2.0, 2.5, 2.887, 3.0, 3.449, 3.556, 3.679, 3.720, 3.8]
colors = ["#000000", "#34d9eb", "#cc33ff", 
          "#ffcc00", "#ff0000", "#34eb3a", 
          "#ff0066", "#0000ff", "#ff00ff"]

# Create 3x3 subplot figure
fig, axes = plt.subplots(3, 3, figsize=(12, 12))
axes = axes.flatten()

for i, (r, color) in enumerate(zip(r_values, colors)):
    x = np.zeros(T)
    x[0] = x0
    for t in range(1, T):
        x[t] = r * x[t-1] * (1 - x[t-1])
    
    ax = axes[i]
    ax.plot(range(T), x, lw=3, color=color, marker='o', markersize=5, markevery=3)

    # Titles and labels
    ax.set_title(f"r = {r}", fontsize=20, fontweight='bold')
    ax.set_xlabel(r"$t$", fontsize=14, fontweight='bold')
    ax.set_ylabel(r"$x_t$", fontsize=14, fontweight='bold')

    # Set y-limits
    ax.set_ylim(0, 1)
    ax.set_xlim(0, T-1)
    ax.grid(False)

    # Boxed style: all spines visible and bold
    for spine in ax.spines.values():
        spine.set_visible(True)
        spine.set_linewidth(2)
    
    ax.tick_params(width=2, labelsize=12)

plt.tight_layout()
fig.savefig("logistic-fig.png", dpi=300)
plt.show()
